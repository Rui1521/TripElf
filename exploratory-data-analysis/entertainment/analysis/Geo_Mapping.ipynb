# %% [markdown]
# ## Load libraries

# %%
import pandas as pd
import numpy as np

import geopandas, fiona
import pyproj    
import shapely
import shapely.ops as ops
from shapely.geometry import Point
from functools import partial

# %% [markdown]
# ## Load data

# %%
restaurants_nyc = pd.read_csv("restaurants_nyc.csv")
shopping_nyc = pd.read_csv("shopping_nyc.csv")
nightlife_nyc = pd.read_csv("nightlife_nyc.csv")

# %%
neighbourhoods_geo = geopandas.read_file("neighbourhoods.geojson")

# %%
neighbourhoods_geo.sort_values("neighbourhood")
# Out:
#                   neighbourhood neighbourhood_group  \
# 1                      Allerton               Bronx
# 7                 Arden Heights       Staten Island
# 8                      Arrochar       Staten Island
# 9                       Arverne              Queens
# 15                      Astoria              Queens
# 16                   Bath Beach            Brooklyn
# 18            Battery Park City           Manhattan
# 10                    Bay Ridge            Brooklyn
# 19                  Bay Terrace              Queens
# 20   Bay Terrace, Staten Island       Staten Island
# 21                   Baychester               Bronx
# 17                      Bayside              Queens
# 22                    Bayswater              Queens
# 0                     Bayswater              Queens
# 23           Bedford-Stuyvesant            Brooklyn
# 24                 Belle Harbor              Queens
# 25                    Bellerose              Queens
# 11                      Belmont               Bronx
# 26                  Bensonhurst            Brooklyn
# 27                 Bergen Beach            Brooklyn
# 28                   Bloomfield       Staten Island
# 29                  Boerum Hill            Brooklyn
# 30                 Borough Park            Brooklyn
# 35                 Breezy Point              Queens
# 36                    Briarwood              Queens
# 31               Brighton Beach            Brooklyn
# 34                    Bronxdale               Bronx
# 37             Brooklyn Heights            Brooklyn
# 38                  Brownsville            Brooklyn
# 39                  Bull's Head       Staten Island
# ..                          ...                 ...
# 207            Theater District           Manhattan
# 208                 Throgs Neck               Bronx
# 209                   Todt Hill       Staten Island
# 200               Tompkinsville       Staten Island
# 210                 Tottenville       Staten Island
# 211                     Tremont               Bronx
# 212                     Tribeca           Manhattan
# 213                 Two Bridges           Manhattan
# 216                   Unionport               Bronx
# 217          University Heights               Bronx
# 218             Upper East Side           Manhattan
# 219             Upper West Side           Manhattan
# 205                    Van Nest               Bronx
# 214                Vinegar Hill            Brooklyn
# 221                   Wakefield               Bronx
# 222          Washington Heights           Manhattan
# 223               West Brighton       Staten Island
# 224                  West Farms               Bronx
# 227                West Village           Manhattan
# 228          Westchester Square               Bronx
# 229                 Westerleigh       Staten Island
# 6                    Whitestone              Queens
# 230              Williamsbridge               Bronx
# 231                Williamsburg            Brooklyn
# 232                 Willowbrook       Staten Island
# 220             Windsor Terrace            Brooklyn
# 225                   Woodhaven              Queens
# 226                    Woodlawn               Bronx
# 180                     Woodrow       Staten Island
# 215                    Woodside              Queens
#
#                                               geometry
# 1    (POLYGON ((-73.848597 40.87167, -73.845823 40....
# 7    (POLYGON ((-74.169827 40.561078, -74.169822999...
# 8    (POLYGON ((-74.06077999999999 40.593188, -74.0...
# 9    (POLYGON ((-73.789535 40.599972, -73.789541 40...
# 15   (POLYGON ((-73.90160299999999 40.76777, -73.90...
# 16   (POLYGON ((-73.99381 40.60195, -73.99961999999...
# 18   (POLYGON ((-74.01375400000001 40.71369, -74.01...
# 10   (POLYGON ((-74.014752 40.633967, -74.014753 40...
# 19   (POLYGON ((-73.770652 40.782078, -73.775599 40...
# 20   (POLYGON ((-74.132614 40.563453, -74.13311 40....
# 21   (POLYGON ((-73.831108 40.865547, -73.829297 40...
# 17   (POLYGON ((-73.74566299999999 40.751578, -73.7...
# 22   (POLYGON ((-73.76506500000001 40.613568, -73.7...
# 0    (POLYGON ((-73.76670799999999 40.614911, -73.7...
# 23   (POLYGON ((-73.941149 40.700281, -73.905479 40...
# 24   (POLYGON ((-73.847319 40.581957, -73.842984 40...
# 25   (POLYGON ((-73.71761600000001 40.744033, -73.7...
# 11   (POLYGON ((-73.880675 40.85716, -73.880743 40....
# 26   (POLYGON ((-73.972998 40.608833, -73.972989 40...
# 27   (POLYGON ((-73.91732 40.631007, -73.903961 40....
# 28   (POLYGON ((-74.16848 40.621562, -74.16922 40.6...
# 29   (POLYGON ((-73.97990299999999 40.687466, -73.9...
# 30   (POLYGON ((-73.988967 40.644122, -73.978532 40...
# 35   (POLYGON ((-73.86265899999999 40.5668, -73.862...
# 36   (POLYGON ((-73.807669 40.715506, -73.807422 40...
# 31   (POLYGON ((-73.96661 40.584575, -73.96521 40.5...
# 34   (POLYGON ((-73.868882 40.857223, -73.856388999...
# 37   (POLYGON ((-73.99887099999999 40.697158, -74.0...
# 38   (POLYGON ((-73.903475 40.675507, -73.90266 40....
# 39   (POLYGON ((-74.14721 40.608259, -74.147502 40....
# ..                                                 ...
# 207  (POLYGON ((-73.985043 40.753554, -73.990724 40...
# 208  (POLYGON ((-73.82623599999999 40.811283, -73.8...
# 209  (POLYGON ((-74.09818 40.610742, -74.0942699999...
# 200  (POLYGON ((-74.078132 40.638172, -74.078087999...
# 210  (POLYGON ((-74.235112 40.520917, -74.233537 40...
# 211  (POLYGON ((-73.897085 40.851972, -73.895563 40...
# 212  (POLYGON ((-74.001886 40.719395, -74.003533 40...
# 213  (POLYGON ((-73.99189800000001 40.709541, -73.9...
# 216  (POLYGON ((-73.838808 40.840763, -73.838657 40...
# 217  (POLYGON ((-73.90107999999999 40.862756, -73.9...
# 218  (POLYGON ((-73.943592 40.782748, -73.943648 40...
# 219  (POLYGON ((-73.958358 40.800369, -73.981438999...
# 205  (POLYGON ((-73.865127 40.841218, -73.868126 40...
# 214  (POLYGON ((-73.97905 40.705967, -73.9790579999...
# 221  (POLYGON ((-73.838392 40.894067, -73.83841 40....
# 222  (POLYGON ((-73.922298 40.855599, -73.924069 40...
# 223  (POLYGON ((-74.097267 40.633998, -74.097155 40...
# 224  (POLYGON ((-73.882576 40.838746, -73.88601 40....
# 227  (POLYGON ((-74.00881 40.742378, -73.996797 40....
# 228  (POLYGON ((-73.842941 40.846404, -73.839125999...
# 229  (POLYGON ((-74.13131 40.626328, -74.1319199999...
# 6    (POLYGON ((-73.79430600000001 40.789062, -73.7...
# 230  (POLYGON ((-73.867216 40.86969, -73.8670099999...
# 231  (POLYGON ((-73.957572 40.725097, -73.952997999...
# 232  (POLYGON ((-74.147066 40.605504, -74.142028 40...
# 220  (POLYGON ((-73.98006100000001 40.660753, -73.9...
# 225  (POLYGON ((-73.86233 40.695962, -73.856544 40....
# 226  (POLYGON ((-73.85946800000001 40.900517, -73.8...
# 180  (POLYGON ((-74.17728200000001 40.54063, -74.17...
# 215  (POLYGON ((-73.90086599999999 40.757674, -73.9...
#
# [233 rows x 3 columns]

# %%
neighbourhoods_geo.head()
# Out:
#       neighbourhood neighbourhood_group  \
# 0         Bayswater              Queens
# 1          Allerton               Bronx
# 2       City Island               Bronx
# 3  Ditmars Steinway              Queens
# 4        Ozone Park              Queens
#
#                                             geometry
# 0  (POLYGON ((-73.76670799999999 40.614911, -73.7...
# 1  (POLYGON ((-73.848597 40.87167, -73.845823 40....
# 2  (POLYGON ((-73.782822 40.843919, -73.782572 40...
# 3  (POLYGON ((-73.90160299999999 40.76777, -73.90...
# 4  (POLYGON ((-73.83754399999999 40.691364, -73.8...

# %%
neighbourhoods_geo.iloc[0]
# Out:
# neighbourhood                                                  Bayswater
# neighbourhood_group                                               Queens
# geometry               (POLYGON ((-73.76670799999999 40.614911, -73.7...
# Name: 0, dtype: object

# %% [markdown]
# ## Neighborhood Area

# %%
polygon_list = list(neighbourhoods_geo["geometry"])
area_list = []
for polygon in polygon_list:
    geom_area = ops.transform(
        partial(
            pyproj.transform,
            pyproj.Proj(init='EPSG:4326'),
            pyproj.Proj(
                proj='aea',
                lat1=polygon.bounds[1],
                lat2=polygon.bounds[3])),
        polygon)
    area_list.append(geom_area.area/1000000)

# %%
neighbourhoods_geo["area"] = area_list

# %% [markdown]
# ## Neighborhood Centroid

# %%
centroid_longitude = []
centroid_latitude = []
for polygon in polygon_list:
    centroid_longitude.append(polygon.centroid.x)
    centroid_latitude.append(polygon.centroid.y)

# %%
neighbourhoods_geo["centroid_longitude"] = centroid_longitude
neighbourhoods_geo["centroid_latitude"] = centroid_latitude

# %%
neighbourhoods_geo.head()
# Out:
#       neighbourhood neighbourhood_group  \
# 0         Bayswater              Queens
# 1          Allerton               Bronx
# 2       City Island               Bronx
# 3  Ditmars Steinway              Queens
# 4        Ozone Park              Queens
#
#                                             geometry      area  \
# 0  (POLYGON ((-73.76670799999999 40.614911, -73.7...  0.235399
# 1  (POLYGON ((-73.848597 40.87167, -73.845823 40....  2.426870
# 2  (POLYGON ((-73.782822 40.843919, -73.782572 40...  1.114446
# 3  (POLYGON ((-73.90160299999999 40.76777, -73.90...  5.456081
# 4  (POLYGON ((-73.83754399999999 40.691364, -73.8...  4.835648
#
#    centroid_longitude  centroid_latitude
# 0          -73.769503          40.617400
# 1          -73.859984          40.864727
# 2          -73.786654          40.846932
# 3          -73.906003          40.777804
# 4          -73.846364          40.679083

# %%
neighbourhoods_geo.to_file("neighbourhoods_nyc.csv", driver="CSV")

# %% [markdown]
# ## Neighborhood Mapping

# %%
def append_neighborhood(df, geo_df):
    # Create a list of Point objects
    point_list = []
    for idx, biz in df.iterrows():
        point_list.append(Point(biz["longitude"], biz["latitude"]))
    
    # Create a list of Polygon
    polygon_list = list(geo_df["geometry"])
    
    neighborhood_list = []
    neighborhood_group_list = []
    flag = True
    for i, point in enumerate(point_list):
        print(i, end='\r', flush=True)
        for j, polygon in enumerate(polygon_list):
            if point.within(polygon):
                neighborhood_list.append(neighbourhoods_geo.iloc[j][0])
                neighborhood_group_list.append(neighbourhoods_geo.iloc[j][1])
                break
            if j == len(polygon_list) - 1:
                neighborhood_list.append(None)
                neighborhood_group_list.append(None)
    
    df["neighborhood"] = neighborhood_list
    df["neighborhood_group"] = neighborhood_group_list
    df = df[~df["neighborhood"].isna()]
    return df

# %%
restaurants_nyc = append_neighborhood(restaurants_nyc, neighbourhoods_geo)
shopping_nyc = append_neighborhood(shopping_nyc, neighbourhoods_geo)
nightlife_nyc = append_neighborhood(nightlife_nyc, neighbourhoods_geo)
# Out:
# 53033

# %%
restaurants_nyc.to_csv("restaurants_nyc.csv", index=False)
shopping_nyc.to_csv("shopping_nyc.csv", index=False)
nightlife_nyc.to_csv("nightlife_nyc.csv", index=False)
